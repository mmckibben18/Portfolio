# %% [markdown]
# # Author: Makayla McKibben
# ## Course: DSC530 Data Exploration and Analysis
# ## Assignment: Week 11 Ex. 11.2
# ## Date: 11.11.2024

# %% [markdown]
# # Chapter 13
#
# Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from os.path import basename, exists


def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + local)


download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkstats2.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkplot.py")

# %%
import thinkstats2
import thinkplot

# %%
import numpy as np
import pandas as pd

# %%
try:
    import empiricaldist
except ImportError:
    # !pip install empiricaldist
# Out:
# Collecting empiricaldist
#   Downloading empiricaldist-0.7.5.tar.gz (12 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: empiricaldist
#   Building wheel for empiricaldist (pyproject.toml): started
#   Building wheel for empiricaldist (pyproject.toml): finished with status 'done'
#   Created wheel for empiricaldist: filename=empiricaldist-0.7.5-py3-none-any.whl size=12481 sha256=e3288fa60616ebd6bdfcd8522a72757bb91c90f9769fb6ecb171b162e94635dc
#   Stored in directory: c:\users\makay\appdata\local\pip\cache\wheels\50\76\80\cd870fa069549e0ac217149202c957ab5a175bea03a287d358
# Successfully built empiricaldist
# Installing collected packages: empiricaldist
# Successfully installed empiricaldist-0.7.5

# %% [markdown]
# ## Survival analysis
#
# If we have an unbiased sample of complete lifetimes, we can compute the survival function from the CDF and the hazard function from the survival function.
#
# Here's the distribution of pregnancy length in the NSFG dataset.

# %%
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/nsfg.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dct")
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dat.gz"
)

# %%
import nsfg

preg = nsfg.ReadFemPreg()
complete = preg.query("outcome in [1, 3, 4]").prglngth
cdf = thinkstats2.Cdf(complete, label="cdf")
# Out:
# C:\Users\makay\Documents\nsfg.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_lb.replace(na_vals, np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:69: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_oz.replace(na_vals, np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:70: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.hpagelb.replace(na_vals, np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.babysex.replace([7, 9], np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:73: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.nbrnaliv.replace([9], np.nan, inplace=True)

# %% [markdown]
# The survival function is just the complementary CDF.

# %%
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/survival.py")
# Out:
# Downloaded survival.py

# %%
import survival


def MakeSurvivalFromCdf(cdf, label=""):
    """Makes a survival function based on a CDF.

    cdf: Cdf

    returns: SurvivalFunction
    """
    ts = cdf.xs
    ss = 1 - cdf.ps
    return survival.SurvivalFunction(ts, ss, label)

# %%
sf = MakeSurvivalFromCdf(cdf, label="survival")

# %%
print(cdf[13])
print(sf[13])
# Out:
# 0.1397801412101171
# 0.8602198587898829

# %% [markdown]
# Here's the CDF and SF.

# %%
thinkplot.Plot(sf)
thinkplot.Cdf(cdf, alpha=0.2)
thinkplot.Config(loc="center left")

# %% [markdown]
# And here's the hazard function.

# %%
hf = sf.MakeHazardFunction(label="hazard")
print(hf[39])
# Out:
# 0.6767068273092369

# %%
thinkplot.Plot(hf)
thinkplot.Config(ylim=[0, 0.75], loc="upper left")

# %% [markdown]
# ## Age at first marriage
#
# We'll use the NSFG respondent file to estimate the hazard function and survival function for age at first marriage.

# %%
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemResp.dct")
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemResp.dat.gz"
)

# %%
resp6 = nsfg.ReadFemResp()

# %% [markdown]
# We have to clean up a few variables.

# %%
resp6["cmmarrhx"] = resp6.cmmarrhx.replace([9997, 9998, 9999], np.nan)
resp6["agemarry"] = (resp6.cmmarrhx - resp6.cmbirth) / 12.0
resp6["age"] = (resp6.cmintvw - resp6.cmbirth) / 12.0

# %% [markdown]
# And the extract the age at first marriage for people who are married, and the age at time of interview for people who are not.

# %%
complete = resp6[resp6.evrmarry == 1].agemarry.dropna()
ongoing = resp6[resp6.evrmarry == 0].age

# %% [markdown]
# The following function uses Kaplan-Meier to estimate the hazard function.

# %%
from collections import Counter


def EstimateHazardFunction(complete, ongoing, label="", verbose=False):
    """Estimates the hazard function by Kaplan-Meier.

    http://en.wikipedia.org/wiki/Kaplan%E2%80%93Meier_estimator

    complete: list of complete lifetimes
    ongoing: list of ongoing lifetimes
    label: string
    verbose: whether to display intermediate results
    """
    if np.sum(np.isnan(complete)):
        raise ValueError("complete contains NaNs")
    if np.sum(np.isnan(ongoing)):
        raise ValueError("ongoing contains NaNs")

    hist_complete = Counter(complete)
    hist_ongoing = Counter(ongoing)

    ts = list(hist_complete | hist_ongoing)
    ts.sort()

    at_risk = len(complete) + len(ongoing)

    lams = pd.Series(index=ts, dtype=float)
    for t in ts:
        ended = hist_complete[t]
        censored = hist_ongoing[t]

        lams[t] = ended / at_risk
        if verbose:
            print(t, at_risk, ended, censored, lams[t])
        at_risk -= ended + censored

    return survival.HazardFunction(lams, label=label)

# %% [markdown]
# Here is the hazard function and corresponding survival function.

# %%
hf = EstimateHazardFunction(complete, ongoing)
thinkplot.Plot(hf)
thinkplot.Config(xlabel="Age (years)", ylabel="Hazard")

# %%
sf = hf.MakeSurvival()
thinkplot.Plot(sf)
thinkplot.Config(xlabel="Age (years)", ylabel="Prob unmarried", ylim=[0, 1])

# %% [markdown]
# ## Quantifying uncertainty
#
# To see how much the results depend on random sampling, we'll use a resampling process again.

# %%
def EstimateMarriageSurvival(resp):
    """Estimates the survival curve.

    resp: DataFrame of respondents

    returns: pair of HazardFunction, SurvivalFunction
    """
    # NOTE: Filling missing values would be better than dropping them.
    complete = resp[resp.evrmarry == 1].agemarry.dropna()
    ongoing = resp[resp.evrmarry == 0].age

    hf = EstimateHazardFunction(complete, ongoing)
    sf = hf.MakeSurvival()

    return hf, sf

# %%
def ResampleSurvival(resp, iters=101):
    """Resamples respondents and estimates the survival function.

    resp: DataFrame of respondents
    iters: number of resamples
    """
    _, sf = EstimateMarriageSurvival(resp)
    thinkplot.Plot(sf)

    low, high = resp.agemarry.min(), resp.agemarry.max()
    ts = np.arange(low, high, 1 / 12.0)

    ss_seq = []
    for _ in range(iters):
        sample = thinkstats2.ResampleRowsWeighted(resp)
        _, sf = EstimateMarriageSurvival(sample)
        ss_seq.append(sf.Probs(ts))

    low, high = thinkstats2.PercentileRows(ss_seq, [5, 95])
    thinkplot.FillBetween(ts, low, high, color="gray", label="90% CI")

# %% [markdown]
# The following plot shows the survival function based on the raw data and a 90% CI based on resampling.

# %%
ResampleSurvival(resp6)
thinkplot.Config(
    xlabel="Age (years)",
    ylabel="Prob unmarried",
    xlim=[12, 46],
    ylim=[0, 1],
    loc="upper right",
)

# %% [markdown]
# The SF based on the raw data falls outside the 90% CI because the CI is based on weighted resampling, and the raw data is not.  You can confirm that by replacing `ResampleRowsWeighted` with `ResampleRows` in `ResampleSurvival`.

# %% [markdown]
# ## More data
#
# To generate survivial curves for each birth cohort, we need more data, which we can get by combining data from several NSFG cycles.

# %%
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/1995FemRespData.dat.gz"
)
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/2006_2010_FemRespSetup.dct"
)
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/2006_2010_FemResp.dat.gz"
)
# Out:
# Downloaded 1995FemRespData.dat.gz
# Downloaded 2006_2010_FemRespSetup.dct
# Downloaded 2006_2010_FemResp.dat.gz

# %%
resp5 = survival.ReadFemResp1995()
resp6 = survival.ReadFemResp2002()
resp7 = survival.ReadFemResp2010()
# Out:
# C:\Users\makay\Documents\survival.py:562: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.timesmar.replace([98, 99], np.nan, inplace=True)
# C:\Users\makay\Documents\survival.py:636: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   resp.cmmarrhx.replace([9997, 9998, 9999], np.nan, inplace=True)
# C:\Users\makay\Documents\survival.py:636: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   resp.cmmarrhx.replace([9997, 9998, 9999], np.nan, inplace=True)
# C:\Users\makay\Documents\survival.py:636: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   resp.cmmarrhx.replace([9997, 9998, 9999], np.nan, inplace=True)

# %%
resps = [resp5, resp6, resp7]

# %% [markdown]
# The following is the code from `survival.py` that generates SFs broken down by decade of birth.

# %%
def AddLabelsByDecade(groups, **options):
    """Draws fake points in order to add labels to the legend.

    groups: GroupBy object
    """
    thinkplot.PrePlot(len(groups))
    for name, _ in groups:
        label = "%d0s" % name
        thinkplot.Plot([15], [1], label=label, **options)


def EstimateMarriageSurvivalByDecade(groups, **options):
    """Groups respondents by decade and plots survival curves.

    groups: GroupBy object
    """
    thinkplot.PrePlot(len(groups))
    for _, group in groups:
        _, sf = EstimateMarriageSurvival(group)
        thinkplot.Plot(sf, **options)


def PlotResampledByDecade(resps, iters=11, predict_flag=False, omit=None):
    """Plots survival curves for resampled data.

    resps: list of DataFrames
    iters: number of resamples to plot
    predict_flag: whether to also plot predictions
    """
    for i in range(iters):
        samples = [thinkstats2.ResampleRowsWeighted(resp) for resp in resps]
        sample = pd.concat(samples, ignore_index=True)
        groups = sample.groupby("decade")

        if omit:
            groups = [(name, group) for name, group in groups if name not in omit]

        # TODO: refactor this to collect resampled estimates and
        # plot shaded areas
        if i == 0:
            AddLabelsByDecade(groups, alpha=0.7)

        if predict_flag:
            PlotPredictionsByDecade(groups, alpha=0.1)
            EstimateMarriageSurvivalByDecade(groups, alpha=0.1)
        else:
            EstimateMarriageSurvivalByDecade(groups, alpha=0.2)

# %% [markdown]
# Here are the results for the combined data.

# %%
PlotResampledByDecade(resps)
thinkplot.Config(
    xlabel="Age (years)", ylabel="Prob unmarried", xlim=[13, 45], ylim=[0, 1]
)

# %% [markdown]
# We can generate predictions by assuming that the hazard function of each generation will be the same as for the previous generation.

# %%
def PlotPredictionsByDecade(groups, **options):
    """Groups respondents by decade and plots survival curves.

    groups: GroupBy object
    """
    hfs = []
    for _, group in groups:
        hf, sf = EstimateMarriageSurvival(group)
        hfs.append(hf)

    thinkplot.PrePlot(len(hfs))
    for i, hf in enumerate(hfs):
        if i > 0:
            hf.Extend(hfs[i - 1])
        sf = hf.MakeSurvival()
        thinkplot.Plot(sf, **options)

# %% [markdown]
# And here's what that looks like.

# %%
PlotResampledByDecade(resps, predict_flag=True)
thinkplot.Config(
    xlabel="Age (years)", ylabel="Prob unmarried", xlim=[13, 45], ylim=[0, 1]
)

# %% [markdown]
# ## Remaining lifetime
#
# Distributions with difference shapes yield different behavior for remaining lifetime as a function of age.

# %%
preg = nsfg.ReadFemPreg()

complete = preg.query("outcome in [1, 3, 4]").prglngth
print("Number of complete pregnancies", len(complete))
ongoing = preg[preg.outcome == 6].prglngth
print("Number of ongoing pregnancies", len(ongoing))

hf = EstimateHazardFunction(complete, ongoing)
sf1 = hf.MakeSurvival()
# Out:
# Number of complete pregnancies 11189
# Number of ongoing pregnancies 352
# C:\Users\makay\Documents\nsfg.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_lb.replace(na_vals, np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:69: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.birthwgt_oz.replace(na_vals, np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:70: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.hpagelb.replace(na_vals, np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.babysex.replace([7, 9], np.nan, inplace=True)
# C:\Users\makay\Documents\nsfg.py:73: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.nbrnaliv.replace([9], np.nan, inplace=True)

# %% [markdown]
# Here's the expected remaining duration of a pregnancy as a function of the number of weeks elapsed.  After week 36, the process becomes "memoryless".

# %%
rem_life1 = sf1.RemainingLifetime()
thinkplot.Plot(rem_life1)
thinkplot.Config(
    title="Remaining pregnancy length", xlabel="Weeks", ylabel="Mean remaining weeks"
)

# %% [markdown]
# And here's the median remaining time until first marriage as a function of age.

# %%
hf, sf2 = EstimateMarriageSurvival(resp6)

# %%
func = lambda pmf: pmf.Percentile(50)
rem_life2 = sf2.RemainingLifetime(filler=np.inf, func=func)

thinkplot.Plot(rem_life2)
thinkplot.Config(
    title="Years until first marriage",
    ylim=[0, 15],
    xlim=[11, 31],
    xlabel="Age (years)",
    ylabel="Median remaining years",
)

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise:**    In NSFG Cycles 6 and 7, the variable `cmdivorcx` contains the date of divorce for the respondent’s first marriage, if applicable, encoded in century-months.
#
# Compute the duration of marriages that have ended in divorce, and the duration, so far, of marriages that are ongoing. Estimate the hazard and survival curve for the duration of marriage.
#
# Use resampling to take into account sampling weights, and plot data from several resamples to visualize sampling error.
#
# Consider dividing the respondents into groups by decade of birth, and possibly by age at first marriage.

# %%
# Defines function clean data which takes respondent info
def CleanData(resp):
    """Cleans respondent data.

    resp: DataFrame
    """
    # Replaces 9998 and 9999 with NaN
    resp["cmdivorcx"] = resp.cmdivorcx.replace([9998, 9999], np.nan)
    # Makes column notdivorced which is turned into an integer column
    resp["notdivorced"] = resp.cmdivorcx.isnull().astype(int)
    # Calculates how long someone was married prior to divorce
    resp["duration"] = (resp.cmdivorcx - resp.cmmarrhx) / 12.0
    # Calculates how long some has been married so far (before divorce)
    resp["durationsofar"] = (resp.cmintvw - resp.cmmarrhx) / 12.0

    # Makes variable month0 which is a timestamp for the beginning of the evaluated time
    month0 = pd.to_datetime("1899-12-15")
    # Calculates how many months it's been since month0
    dates = [month0 + pd.DateOffset(months=cm) for cm in resp.cmbirth]
    # Groups respondents by decades by dividing total years since month0 by 10
    resp["decade"] = (pd.DatetimeIndex(dates).year - 1900) // 10

# %%
# Clean the data from respondents 6
CleanData(resp6)
# Select those that have ever been married
married6 = resp6[resp6.evrmarry == 1]
# Clean the data from respondents 7
CleanData(resp7)
# Select those that have ever been married
married7 = resp7[resp7.evrmarry == 1]

# %%
# Solution

# Define function to resample divorcees
def ResampleDivorceCurve(resps):
    """Plots divorce curves based on resampled data.

    resps: list of respondent DataFrames
    """
    # Create for loop to iterate through 11 times
    for _ in range(11):
        # Resample
        samples = [thinkstats2.ResampleRowsWeighted(resp) for resp in resps]
        # Create df from resampled data ignoring the index
        sample = pd.concat(samples, ignore_index=True)
        # Plot curve with resampled data
        PlotDivorceCurveByDecade(sample, color="#225EA8", alpha=0.1)
    # Show plot
    thinkplot.Show(xlabel="years", axis=[0, 28, 0, 1])

# %%
# Solution

# Define EstimateSurvival
def EstimateSurvival(resp):
    """Estimates the survival curve.

    resp: DataFrame of respondents

    returns: pair of HazardFunction, SurvivalFunction
    """
    # Finds those who've been divorced
    complete = resp[resp.notdivorced == 0].duration.dropna()
    # Finds those who've been divorced
    ongoing = resp[resp.notdivorced == 1].durationsofar.dropna()

    # Make the hazard function
    hf = survival.EstimateHazardFunction(complete, ongoing)
    # Make survival function
    sf = hf.MakeSurvival()

    # Return the hazard function and survival function
    return hf, sf

# %%
# Solution

# Define function EstimateSurvivalByDecade
def EstimateSurvivalByDecade(groups, **options):
    """Groups respondents by decade and plots survival curves.

    groups: GroupBy object
    """
    thinkplot.PrePlot(len(groups))
    # For loop to iterate through all the groups
    for name, group in groups:
        # Estimate survival of the group 
        _, sf = EstimateSurvival(group)
        # Plot survival function
        thinkplot.Plot(sf, **options)

# %%
# Solution

# Define function that resamples by decade
def ResampleDivorceCurveByDecade(resps):
    """Plots divorce curves for each birth cohort.

    resps: list of respondent DataFrames
    """
    # For loop that iterates through 41
    for i in range(41):
        # Resample
        samples = [thinkstats2.ResampleRowsWeighted(resp) for resp in resps]
        # Create df from resampled data
        sample = pd.concat(samples, ignore_index=True)
        # Group samples by decade
        groups = sample.groupby("decade")
        # Add labels
        if i == 0:
            survival.AddLabelsByDecade(groups, alpha=0.7)

        # Calculate survival by decade
        EstimateSurvivalByDecade(groups, alpha=0.1)
    # Plot decade results
    thinkplot.Config(xlabel="Years", ylabel="Fraction undivorced", axis=[0, 28, 0, 1])

# %%
# Solution
# Plot resampled data for respondent 6 and 7 values
ResampleDivorceCurveByDecade([married6, married7])
